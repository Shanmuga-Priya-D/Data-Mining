# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
df=pd.read_csv('online_retail.csv')
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df['Description']=df['Description'].str.strip() # remove spaces at beginning and end of string
df.dropna(axis=0,subset=['Invoice'],inplace=True) # dropping rows which contain null values in invoice column 
df['Invoice']=df['Invoice'].astype('str') # to change datatype
df=df[-df['Invoice'].str.contains('C')]
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 1067367  581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138         BAKING SET 9 PIECE RETROSPOT         3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
# taking only france data
basket=(df[df['Country']=="France"]
       .groupby(['Invoice','Description'])['Quantity']
                 .sum().unstack().reset_index().fillna(0)
                 .set_index('Invoice'))
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# Invoice
# 489439                          0.0                         0.0
# 489557                          0.0                         0.0
# 489883                          0.0                         0.0
# 490139                          0.0                         0.0
# 490152                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 IVORY ROSE PEG PLACE SETTINGS  \
# Invoice
# 489439                             0.0                               0.0
# ...

# %%
def encode_units(x):
    if x<=0:
        return 0
    if x>=1:
        return 1
basket_sets=basket.applymap(encode_units)
basket_sets.drop('POSTAGE',inplace=True,axis=1)
basket_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# Invoice
# 489439                            0                           0
# 489557                            0                           0
# 489883                            0                           0
# 490139                            0                           0
# 490152                            0                           0
# ...                             ...                         ...
# 580986                            0                           0
# 581001                            0                           0
# 581171                            0                           0
# 581279                            0                           0
# 581587                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 IVORY ROSE PEG PLACE SETTINGS  \
# Invoice
# 489439                               0                                 0
# ...

# %%
frequent_itemsets=apriori(basket_sets,min_support=0.07,use_colnames=True)
rules=association_rules(frequent_itemsets,metric='lift',min_threshold=1)
rules.head()
# Out:
#                            antecedents                          consequents  \
# 0               (DOLLY GIRL LUNCH BOX)                 (SPACEBOY LUNCH BOX)
# 1                 (SPACEBOY LUNCH BOX)               (DOLLY GIRL LUNCH BOX)
# 2   (LUNCH BOX WITH CUTLERY RETROSPOT)  (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 3  (STRAWBERRY LUNCH BOX WITH CUTLERY)   (LUNCH BOX WITH CUTLERY RETROSPOT)
# 4      (PLASTERS IN TIN CIRCUS PARADE)           (PLASTERS IN TIN SPACEBOY)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.094855            0.128617  0.072347    0.762712  5.930085
# 1            0.128617            0.094855  0.072347    0.562500  5.930085
# 2            0.151125            0.128617  0.081994    0.542553  4.218351
# 3            0.128617            0.151125  0.081994    0.637500  4.218351
# 4            0.167203            0.128617  0.090032    0.538462  4.186538
#
#    leverage  conviction
# 0  0.060147    3.672255
# ...

# %%
rules[(rules['lift']>=6)&(rules['confidence']>=0.8)]
# Out:
#                                           antecedents  \
# 16                    (SET/6 RED SPOTTY PAPER PLATES)
# 17                      (SET/6 RED SPOTTY PAPER CUPS)
# 19  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 20  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
#
#                         consequents  antecedent support  consequent support  \
# 16    (SET/6 RED SPOTTY PAPER CUPS)            0.125402            0.136656
# 17  (SET/6 RED SPOTTY PAPER PLATES)            0.136656            0.125402
# 19  (SET/6 RED SPOTTY PAPER PLATES)            0.072347            0.125402
# 20    (SET/6 RED SPOTTY PAPER CUPS)            0.072347            0.136656
#
#      support  confidence      lift  leverage  conviction
# 16  0.114148    0.910256  6.660935  0.097011    9.620119
# 17  0.114148    0.835294  6.660935  0.097011    5.310060
# 19  0.070740    0.977778  7.797151  0.061667   39.356913
# 20  0.070740    0.977778  7.155033  0.060853   38.850482
